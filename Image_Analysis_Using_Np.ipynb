# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image  #Python Image Library

# %%
img = Image.open(r"C:\Users\IT\Desktop\photo\employee.WEBP")
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1380x776>

# %%
my_img = Image.open(r"C:\Users\IT\Desktop\photo\Employee1.jpeg")

# %%
my_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
image = Image.open(r"C:\Users\IT\Desktop\photo\employee2.jpeg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=332x152>

# %%
i = Image.open(r"C:\Users\IT\Desktop\photo\images.jpeg")
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x159>

# %%
p = Image.open(r"C:\Users\IT\Desktop\photo\office.jpeg")
p
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
